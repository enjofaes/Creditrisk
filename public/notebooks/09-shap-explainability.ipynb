# %% [markdown]
# # SHAP Explainability

# %%
# Install shap: pip install shap
# import shap
# explainer = shap.TreeExplainer(model)
# shap_values = explainer.shap_values(X_test)
print("See xgboost notebook for full SHAP analysis")
